# %% [markdown]
# <a href="https://colab.research.google.com/github/ajita-asthana/Node-tuts/blob/master/asthana_ajeeta_taxi_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
taxi = pd.read_csv("http://becomingvisual.com/python4data/taxi2016.csv", header = 0)
taxi.head(5)
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2          1/1/16 0:00           1/1/16 0:00                2
# 1         2          1/1/16 0:00           1/1/16 0:00                5
# 2         2          1/1/16 0:00           1/1/16 0:00                1
# 3         2          1/1/16 0:00           1/1/16 0:00                1
# 4         2          1/1/16 0:00           1/1/16 0:00                3
#
#    trip_distance  pickup_longitude  pickup_latitude  RatecodeID  \
# 0           1.10        -73.990372        40.734695           1
# 1           4.90        -73.980782        40.729912           1
# 2          10.54        -73.984550        40.679565           1
# 3           4.75        -73.993469        40.718990           1
# 4           1.76        -73.960625        40.781330           1
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# ...

# %%
taxi.dtypes
# Out:
# VendorID                   int64
# tpep_pickup_datetime      object
# tpep_dropoff_datetime     object
# passenger_count            int64
# trip_distance            float64
# pickup_longitude         float64
# pickup_latitude          float64
# RatecodeID                 int64
# store_and_fwd_flag        object
# dropoff_longitude        float64
# dropoff_latitude         float64
# payment_type               int64
# fare_amount              float64
# extra                    float64
# mta_tax                  float64
# tip_amount               float64
# tolls_amount             float64
# improvement_surcharge    float64
# total_amount             float64
# dtype: object

# %%
taxi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   VendorID               1048575 non-null  int64
#  1   tpep_pickup_datetime   1048575 non-null  object
#  2   tpep_dropoff_datetime  1048575 non-null  object
#  3   passenger_count        1048575 non-null  int64
#  4   trip_distance          1048575 non-null  float64
#  5   pickup_longitude       1048575 non-null  float64
#  6   pickup_latitude        1048575 non-null  float64
#  7   RatecodeID             1048575 non-null  int64
#  8   store_and_fwd_flag     1048575 non-null  object
#  9   dropoff_longitude      1048575 non-null  float64
#  10  dropoff_latitude       1048575 non-null  float64
#  11  payment_type           1048575 non-null  int64
#  12  fare_amount            1048575 non-null  float64
#  13  extra                  1048575 non-null  float64
# ...

# %%
newvalues = taxi.loc[:, "passenger_count"].astype('float64')

# %%
taxi.loc[:, "passenger_count"] = newvalues

# %%
newvalues
# Out:
# 0          2.0
# 1          5.0
# 2          1.0
# 3          1.0
# 4          3.0
#           ...
# 1048570    1.0
# 1048571    1.0
# 1048572    1.0
# 1048573    1.0
# 1048574    1.0
# Name: passenger_count, Length: 1048575, dtype: float64

# %%
taxi.dtypes
# Out:
# VendorID                   int64
# tpep_pickup_datetime      object
# tpep_dropoff_datetime     object
# passenger_count          float64
# trip_distance            float64
# pickup_longitude         float64
# pickup_latitude          float64
# RatecodeID                 int64
# store_and_fwd_flag        object
# dropoff_longitude        float64
# dropoff_latitude         float64
# payment_type               int64
# fare_amount              float64
# extra                    float64
# mta_tax                  float64
# tip_amount               float64
# tolls_amount             float64
# improvement_surcharge    float64
# total_amount             float64
# dtype: object

# %%
newvalues = taxi.loc[:,"passenger_count"].astype('int64')
taxi.loc[:, "passenger_count"] = newvalues

# %%
taxi.dtypes
# Out:
# VendorID                   int64
# tpep_pickup_datetime      object
# tpep_dropoff_datetime     object
# passenger_count            int64
# trip_distance            float64
# pickup_longitude         float64
# pickup_latitude          float64
# RatecodeID                 int64
# store_and_fwd_flag        object
# dropoff_longitude        float64
# dropoff_latitude         float64
# payment_type               int64
# fare_amount              float64
# extra                    float64
# mta_tax                  float64
# tip_amount               float64
# tolls_amount             float64
# improvement_surcharge    float64
# total_amount             float64
# dtype: object

# %%
newvalues = pd.to_datetime(taxi.loc[:, "tpep_pickup_datetime"])
taxi.loc[:, "tpep_pickup_datetime"] = newvalues
taxi.dtypes
# Out:
# VendorID                          int64
# tpep_pickup_datetime     datetime64[ns]
# tpep_dropoff_datetime            object
# passenger_count                   int64
# trip_distance                   float64
# pickup_longitude                float64
# pickup_latitude                 float64
# RatecodeID                        int64
# store_and_fwd_flag               object
# dropoff_longitude               float64
# dropoff_latitude                float64
# payment_type                      int64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# improvement_surcharge           float64
# total_amount                    float64
# dtype: object

# %%
newvalues = pd.to_datetime(taxi.loc[:, "tpep_dropoff_datetime"])
taxi.loc[:, "tpep_dropoff_datetime"] = newvalues
taxi.dtypes
# Out:
# VendorID                          int64
# tpep_pickup_datetime     datetime64[ns]
# tpep_dropoff_datetime    datetime64[ns]
# passenger_count                   int64
# trip_distance                   float64
# pickup_longitude                float64
# pickup_latitude                 float64
# RatecodeID                        int64
# store_and_fwd_flag               object
# dropoff_longitude               float64
# dropoff_latitude                float64
# payment_type                      int64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# improvement_surcharge           float64
# total_amount                    float64
# dtype: object

# %%
taxi_subset = taxi.loc[taxi.passenger_count == 1]
taxi_subset.head(5)
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 2         2           2016-01-01   2016-01-01 00:00:00                1
# 3         2           2016-01-01   2016-01-01 00:00:00                1
# 7         1           2016-01-01   2016-01-01 00:11:00                1
# 8         1           2016-01-01   2016-01-01 00:11:00                1
# 9         2           2016-01-01   2016-01-01 00:11:00                1
#
#    trip_distance  pickup_longitude  pickup_latitude  RatecodeID  \
# 2          10.54        -73.984550        40.679565           1
# 3           4.75        -73.993469        40.718990           1
# 7           1.20        -73.979424        40.744614           1
# 8           6.00        -73.947151        40.791046           1
# 9           3.21        -73.998344        40.723896           1
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# ...

# %%
taxi_subset
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 2               2  2016-01-01 00:00:00   2016-01-01 00:00:00                1
# 3               2  2016-01-01 00:00:00   2016-01-01 00:00:00                1
# 7               1  2016-01-01 00:00:00   2016-01-01 00:11:00                1
# 8               1  2016-01-01 00:00:00   2016-01-01 00:11:00                1
# 9               2  2016-01-01 00:00:00   2016-01-01 00:11:00                1
# ...           ...                  ...                   ...              ...
# 1048570         1  2016-01-04 17:28:00   2016-01-04 17:36:00                1
# 1048571         1  2016-01-04 17:28:00   2016-01-04 17:49:00                1
# 1048572         1  2016-01-04 17:28:00   2016-01-04 18:08:00                1
# 1048573         1  2016-01-04 17:28:00   2016-01-04 17:32:00                1
# 1048574         1  2016-01-04 17:28:00   2016-01-04 17:35:00                1
#
# ...

# %%
taxi_subset.reset_index(inplace = True, drop = False)

# %%
taxi_subset
# Out:
#           index  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0             2         2  2016-01-01 00:00:00   2016-01-01 00:00:00
# 1             3         2  2016-01-01 00:00:00   2016-01-01 00:00:00
# 2             7         1  2016-01-01 00:00:00   2016-01-01 00:11:00
# 3             8         1  2016-01-01 00:00:00   2016-01-01 00:11:00
# 4             9         2  2016-01-01 00:00:00   2016-01-01 00:11:00
# ...         ...       ...                  ...                   ...
# 701852  1048570         1  2016-01-04 17:28:00   2016-01-04 17:36:00
# 701853  1048571         1  2016-01-04 17:28:00   2016-01-04 17:49:00
# 701854  1048572         1  2016-01-04 17:28:00   2016-01-04 18:08:00
# 701855  1048573         1  2016-01-04 17:28:00   2016-01-04 17:32:00
# 701856  1048574         1  2016-01-04 17:28:00   2016-01-04 17:35:00
#
#         passenger_count  trip_distance  pickup_longitude  pickup_latitude  \
# ...

# %%
#calculate average tip amount 
cust_avg_tip_amt = sum(taxi_subset.tip_amount) / taxi_subset.shape[0]
cust_avg_tip_amt
# Out:
# 1.5173728978977554

# %%
taxi_subset.tip_amount.mean()
# Out:
# 1.517372897898005

# %%
taxi_subset.fare_amount.mean()
# Out:
# 12.397635316025916

# %%
# find range min, max
taxi_subset.describe()
# Out:
#               index       VendorID  passenger_count  trip_distance  \
# count  7.018570e+05  701857.000000         701857.0   7.018570e+05
# mean   5.402985e+05       1.447925              1.0   1.541061e+01
# std    3.082967e+05       0.497281              0.0   9.579025e+03
# min    2.000000e+00       1.000000              1.0   0.000000e+00
# 25%    2.715380e+05       1.000000              1.0   1.000000e+00
# 50%    5.441110e+05       1.000000              1.0   1.790000e+00
# 75%    8.120470e+05       2.000000              1.0   3.400000e+00
# max    1.048574e+06       2.000000              1.0   8.000010e+06
#
#        pickup_longitude  pickup_latitude     RatecodeID  dropoff_longitude  \
# count     701857.000000    701857.000000  701857.000000      701857.000000
# mean         -72.658424        40.027262       1.043314         -72.716525
# std            9.765014         5.379454       0.472436           9.553603
# ...

# %%
print("The maximum tip was: ", taxi_subset.fare_amount.min())
print("The maximum tip was: ", taxi_subset.fare_amount.max())
print("The range of the tip was: ", taxi_subset.fare_amount.min(),":",taxi_subset.fare_amount.max())
# Out:
# The maximum tip was:  -300.0
# The maximum tip was:  1463.75
# The range of the tip was:  -300.0 : 1463.75

# %%
print(len(taxi_subset.loc[taxi_subset.fare_amount == -300]))
taxi_subset.loc[taxi_subset.fare_amount == -300]
# Out:
# 1
#          index  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 124590  193432         2  2016-01-01 09:06:00   2016-01-01 09:11:00
#
#         passenger_count  trip_distance  pickup_longitude  pickup_latitude  \
# 124590                1            0.0        -73.989738        40.714378
#
#         RatecodeID store_and_fwd_flag  dropoff_longitude  dropoff_latitude  \
# 124590           5                  N         -73.989693         40.714432
#
#         payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 124590             4       -300.0    0.0     -0.5         0.0           0.0
#
#         improvement_surcharge  total_amount
# 124590                   -0.3        -300.8

# %%
taxi.groupby(['passenger_count']).size()
# Out:
# passenger_count
# 0        59
# 1    701857
# 2    177159
# 3     52765
# 4     30259
# 5     54017
# 6     32451
# 7         3
# 8         5
# dtype: int64

# %%
taxi.groupby(by=['payment_type']).size()
# Out:
# payment_type
# 1    594378
# 2    447875
# 3      4664
# 4      1658
# dtype: int64

# %%
#calculate the total distance, total fare, mean tip amount 
taxi.groupby(by=['payment_type'])['trip_distance','tip_amount', 'total_amount'].mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#               trip_distance  tip_amount  total_amount
# payment_type
# 1                  3.451713    2.694059     17.506710
# 2                 22.182675    0.000072     13.085020
# 3                  3.328171   -0.000540     13.987985
# 4                  3.316912   -0.000145     12.960440

# %%
 x = taxi.groupby(by=['payment_type'])['trip_distance','tip_amount', 'total_amount'].mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4 entries, 1 to 4
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   trip_distance  4 non-null      float64
#  1   tip_amount     4 non-null      float64
#  2   total_amount   4 non-null      float64
# dtypes: float64(3)
# memory usage: 128.0 bytes

# %%
taxi.groupby(by=['payment_type'])['trip_distance','tip_amount','total_amount'].max()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#               trip_distance  tip_amount  total_amount
# payment_type
# 1                     518.2      998.14       1004.94
# 2                 8000010.0       11.67       1463.75
# 3                     199.2        2.16        656.15
# 4                     208.1        1.46        500.30
